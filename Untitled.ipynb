# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('sanbul.csv',encoding='cp949')
df.columns = df.columns.str.replace(' ','')
df.head()
# Out:
#    발생일시_년  발생일시_월  발생일시_일 발생일시_시간 발생일시_요일  진화종료시간_년  진화종료시간_월  진화종료시간_일  \
# 0    2019       6      12   15:23       수      2019         6        12
# 1    2019       6       6   13:32       목      2019         6         6
# 2    2019       6       6   12:15       목      2019         6         6
# 3    2019       6       6   10:11       목      2019         6         6
# 4    2019       6       5   17:00       수      2019         6         5
#
#   진화종료시간_시간 발생장소_관서 발생장소_시도 발생장소_시군구 발생장소_읍면 발생장소_동리 발생장소_지번 발생원인_구분  \
# 0     16:28      경북      경북       경산      진량      평사     산10       입
# 1     15:39      경북      경북       경산      진량      아사   산59-1       쓰
# 2     14:50      경북      경북       경주      안강      강교    산124       논
# 3     12:08      서울      서울       강북      우이     NaN   199-2       기
# 4     20:00      경북      경북       경주      외동      제내   산20-1       입
#
#   발생원인_세부원인   발생원인_기타  피해면적_합계
# 0  기타(직접입력)  입산자 실화추정     0.01
# 1    쓰레기 소각       NaN     0.03
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7420 entries, 0 to 7419
# Data columns (total 19 columns):
# 발생일시_년       7420 non-null int64
# 발생일시_월       7420 non-null int64
# 발생일시_일       7420 non-null int64
# 발생일시_시간      7420 non-null object
# 발생일시_요일      7420 non-null object
# 진화종료시간_년     7420 non-null int64
# 진화종료시간_월     7420 non-null int64
# 진화종료시간_일     7420 non-null int64
# 진화종료시간_시간    7420 non-null object
# 발생장소_관서      7420 non-null object
# 발생장소_시도      7420 non-null object
# 발생장소_시군구     7420 non-null object
# 발생장소_읍면      7272 non-null object
# 발생장소_동리      5972 non-null object
# 발생장소_지번      7339 non-null object
# 발생원인_구분      7420 non-null object
# 발생원인_세부원인    7419 non-null object
# 발생원인_기타      993 non-null object
# 피해면적_합계      7420 non-null float64
# dtypes: float64(1), int64(6), object(12)
# memory usage: 1.1+ MB

# %%
f, ax=plt.subplots(figsize=(17,17))
sns.heatmap(df.corr(),annot=True, linewidth=.5, fmt='.2f', ax=ax)
plt.show()

# %%
map2 = folium.Map(location=[a["위도"][1], a["경도"][1]], 
zoom_start=11)
for n in a.index:folium.CircleMarker([a["위도"][n], 
a["경도"][n]], radius=1, popup=a["상호명"][n], 
color="#F42105").add_to(map2)
