# %%
import folium

# %%
places_on_SAF = [
('Desert Hot Springs', 39.9611, -116.5017),
('Salton Sea State Recreation Area', 33.5088, -115.9181)]

# get the coordinates for these places
lats = [x[1] for x in places_on_SAF]
lons = [x[2] for x in places_on_SAF]
coordinates = zip(lats, lons)
# list(coordinates)

# %%
m = folium.Map(location=[36.5,-122], zoom_start=6, tiles='Stamen Terrain')
# Create the map with the appoximate location of San Andreas Fault
SAF=folium.PolyLine(locations=coordinates,weight=5,color = 'red')
m.add_children(SAF)
# Out:
# C:\Users\noteland\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
#   after removing the cwd from sys.path.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
places_on_SAF = [('Point Delgada', 40.0215325, -124.0691973),

('Salton Sea State Recreation Area', 33.5088, -115.9181)]

# get the coordinates for these places
lats = [x[1] for x in places_on_SAF]
lons = [x[2] for x in places_on_SAF]
coordinates = zip(lats, lons)
coordinates

# %%
m = folium.Map(location=[36.5,-122], zoom_start=6, tiles='Stamen Terrain')
# Create the map with the appoximate location of San Andreas Fault
SAF=folium.PolyLine(locations=coordinates,weight=5,color = 'red')
m.add_children(SAF)
# Out:
# C:\Users\noteland\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
#   after removing the cwd from sys.path.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
import numpy as np
import pandas as pd
import math
from collections import namedtuple
# using omaha coordinates 
center_lat = 41.257160
center_lon = 95.995102
# generating a couple of random latlongs in the omaha area
lats = np.random.uniform(low=center_lat - .25, high=center_lat +    .25, size=(2,))
lons = np.random.uniform(low=center_lon - .25, high=center_lon + .25, size=(2,))
PI = 3.14
angle = PI * (270 / 180); 
# angle=30
p1 = [lats[0], lons[0]]
p2 = [lats[0]+(2*math.cos(angle)),lons[0]+( 2*math.sin(angle))]
print(p1)
print(p2)
# Out:
# [41.213182555731706, 95.84711536212883]
# [41.20840459950714, 93.84712106935339]

# %%
some_map = folium.Map(location=[center_lat, center_lon], zoom_start=10)
folium.Marker(location=p1,     icon=folium.Icon(color='green')).add_to(some_map)
# folium.Marker(location=p2, icon=folium.Icon(color='red')).add_to(some_map)
folium.PolyLine(locations=[p1, p2], color='blue').add_to(some_map)
arrows = get_arrows(locations=[p2, p1], n_arrows=3)
for arrow in arrows:
    arrow.add_to(some_map)
some_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-bfe659873686> in <module>
#       3 # folium.Marker(location=p2, icon=folium.Icon(color='red')).add_to(some_map)
#       4 folium.PolyLine(locations=[p1, p2], color='blue').add_to(some_map)
# ----> 5 arrows = get_arrows(locations=[p2, p1], n_arrows=3)
#       6 for arrow in arrows:
#       7     arrow.add_to(some_map)
#
# NameError: name 'get_arrows' is not defined

# %%
def get_arrows(locations, color='blue', size=6, n_arrows=3):
    
    '''
    Get a list of correctly placed and rotated 
    arrows/markers to be plotted
    
    Parameters
    locations : list of lists of lat lons that represent the 
                start and end of the line. 
                eg [[41.1132, -96.1993],[41.3810, -95.8021]]
    arrow_color : default is 'blue'
    size : default is 6
    n_arrows : number of arrows to create.  default is 3
    Return
    list of arrows/markers
    '''
    
    Point = namedtuple('Point', field_names=['lat', 'lon'])
    
    # creating point from our Point named tuple
    p1 = Point(locations[0][0], locations[0][1])
    p2 = Point(locations[1][0], locations[1][1])
    
    # getting the rotation needed for our marker.  
    # Subtracting 90 to account for the marker's orientation
    # of due East(get_bearing returns North)
    rotation = get_bearing(p1, p2) - 90
    
    # get an evenly space list of lats and lons for our arrows
    # note that I'm discarding the first and last for aesthetics
    # as I'm using markers to denote the start and end
    arrow_lats = np.linspace(p1.lat, p2.lat, n_arrows + 2)[1:n_arrows+1]
    arrow_lons = np.linspace(p1.lon, p2.lon, n_arrows + 2)[1:n_arrows+1]
    
    arrows = []
    
    #creating each "arrow" and appending them to our arrows list
    for points in zip(arrow_lats, arrow_lons):
        arrows.append(folium.RegularPolygonMarker(location=points, 
                      fill_color=color, number_of_sides=3, 
                      radius=size, rotation=rotation))
    return arrows

# %%
def get_bearing(p1, p2):
    
    '''
    Returns compass bearing from p1 to p2
    
    Parameters
    p1 : namedtuple with lat lon
    p2 : namedtuple with lat lon
    
    Return
    compass bearing of type float
    
    Notes
    Based on https://gist.github.com/jeromer/2005586
    '''
    
    long_diff = np.radians(p2.lon - p1.lon)
    
    lat1 = np.radians(p1.lat)
    lat2 = np.radians(p2.lat)
    
    x = np.sin(long_diff) * np.cos(lat2)
    y = (np.cos(lat1) * np.sin(lat2) 
        - (np.sin(lat1) * np.cos(lat2) 
        * np.cos(long_diff)))
    bearing = np.degrees(np.arctan2(x, y))
    
    # adjusting for compass bearing
    if bearing < 0:
        return bearing + 360
    return bearing

# %%
print(math.sin(30) )
print(math.cos(30))
# Out:
# -0.9880316240928618
# 0.15425144988758405

# %%
df = pd.read_csv('C:\\Users\\noteland\\Documents\\forest\\sanbul2.csv',encoding='cp949')
df.columns = df.columns.str.replace(' ','')
df.head()
# Out:
#    발생일시_년  발생일시_월  발생일시_일 발생일시_시간 발생일시_요일  진화종료시간_년  진화종료시간_월  진화종료시간_일  \
# 0    2019       4       4   23:46       목      2019         4         5
# 1    2019       4       4   19:17       목      2019         4         5
# 2    2005       4       4   23:53       화      2005         4         6
# 3    2017       5       6   11:42       토      2017         5         9
# 4    2004       3      16   23:35       화      2004         3        17
#
#   진화종료시간_시간 발생장소_관서  ...  피해면적_합계        X-좌표       Y-좌표  \
# 0     21:30      강원  ...  1260.00  129.011529  37.571928
# 1     18:00      강원  ...  1227.00  128.502773  38.205705
# 2      8:00      강원  ...   973.00  128.559295  38.100077
# 3     11:20      강원  ...   765.12  129.014154  37.254183
# 4     13:00      강원  ...   430.00  128.986612  37.595132
#
#                     정제결과 종관기상관측소 방재기상관측소    기온  습도   풍향    풍속
# 0    강원도 강릉시 옥계면 남양리 958     106     580  15.2  14  270  10.0
# 1  강원도 고성군 토성면 원암리 산89-2      90     520  15.8  19  270   5.6
# ...

# %%
df = df[['발생일시_년', '발생일시_월','발생장소_시도','발생장소_시군구','X-좌표','Y-좌표','발생원인_세부원인','피해면적_합계']]
df.head(20)
# Out:
#     발생일시_년  발생일시_월 발생장소_시도 발생장소_시군구        X-좌표       Y-좌표  발생원인_세부원인  피해면적_합계
# 0     2019       4     강원도      강릉시  129.011529  37.571928   기타(직접입력)  1260.00
# 1     2019       4     강원도      고성군  128.502773  38.205705   기타(직접입력)  1227.00
# 2     2005       4     강원도      양양군  128.559295  38.100077    입산자실화추정   973.00
# 3     2017       5     강원도      삼척시  129.014154  37.254183   기타(직접입력)   765.12
# 4     2004       3     강원도      강릉시  128.986612  37.595132       방화추정   430.00
# 5     2009       4    경상북도      칠곡군  128.500812  35.999808    입산자실화추정   407.00
# 6     2018       3     강원도      고성군  128.467967  38.357454   기타(직접입력)   356.85
# 7     2019       4     강원도      인제군  128.130899  38.028493       원인미상   345.00
# 8     2013       3   울산광역시      울주군  129.104244  35.580453      쓰레기소각   280.00
# 9     2017       5     강원도      강릉시  128.804265  37.722522   기타(직접입력)   252.00
# 10    2005       4    경상남도      함양군  127.683220  35.539768      성묘객실화   229.00
# ...

# %%
df = pd.read_csv('C:\\Users\\noteland\\Documents\\forest\\sanbul2.csv',encoding='cp949')
df.columns = df.columns.str.replace(' ','')
df = df.loc[ (df['발생장소_시도'] =='강원도'), :]
df = df.loc[ (df['발생장소_시군구'] =='삼척시'), :]
df = df.loc[ (df['발생일시_년'] ==2017), :]
df = df.loc[ (df['발생일시_월'] ==5), :]
df = df.loc[ (df['발생일시_일'] ==6), :]

# %%
df = pd.read_csv('C:\\Users\\noteland\\Documents\\forest\\sanbul2.csv',encoding='cp949')
df.columns = df.columns.str.replace(' ','')
df = df.loc[ (df['피해면적_합계'] >10), :]

# %%
map_osm = folium.Map(location=(37.56629, 126.979808), zoom_start=17)
# map_osm
시청_좌표=(37.56629, 126.979808)
map_osm = folium.Map(location=시청_좌표, zoom_start=11)



some_map = folium.Map(location=[37.56629, 126.979808], zoom_start=10)
for ix, row in df.iterrows():
    PI = 3.14
    angle = PI * (abs(int(row['풍향']-360)) / 180); 
#     print(int(row['풍향']))
#     row['Y-좌표']=37.56629
#     row['X-좌표']=133.979808
    p1 = [lats[0], lons[0]]
    p2 = [(row['Y-좌표'])+((row['풍속']*0.1)*math.cos(angle)),(row['X-좌표'])+((row['풍속']*0.1)*math.sin(angle))]
    p1 = (row['Y-좌표'], row['X-좌표'])
#     print(row['발생장소_시군구'])
#     print(p1)
#     print(p2)
    
    folium.Marker(p1,icon=folium.Icon(color='red', icon='fire',angle=30, prefix='glyphicon'), popup=row['발생일시_년']).add_to(some_map)
    folium.CircleMarker(p1,radius=row['피해면적_합계']/100,color='#3186cc',fill_color='#3186cc', popup=row['피해면적_합계']).add_to(some_map)
    folium.PolyLine(locations=[p1, p2], color='green').add_to(some_map)
    arrows = get_arrows(locations=[p1, p2], n_arrows=2)
    for arrow in arrows:
        arrow.add_to(some_map)
    
        
some_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for ix, row in df.iterrows():
     print(row['Y-좌표'],row['X-좌표'])
     p2 = [int(row['Y-좌표'])+(int(row['풍속'])*math.cos(angle)),int(row['X-좌표'])+(int(row['풍속'])*math.sin(angle))]
     print(p2)
# Out:
# 37.5719276 129.011529
# [27.000012682724606, 129.01592652916486]
# 38.2057051 128.502773
# [33.0000063413623, 128.00796326458243]
# 38.1000769 128.559295
# [34.000005073089845, 128.00637061166594]
# 37.25418320000001 129.014154
# [34.00000380481738, 129.00477795874946]
# 37.5951318 128.986612
# [36.00000126827246, 128.0015926529165]
# 35.9998078 128.50081200000002
# [31.00000507308984, 128.00637061166594]
# 38.3574544 128.467967
# [36.00000253654492, 128.00318530583297]
# 38.028492799999995 128.130899
# [33.0000063413623, 128.00796326458243]
# 35.580453399999996 129.104244
# [32.00000380481738, 129.00477795874946]
# 37.7225222 128.804265
# [25.000015219269528, 128.01911183499783]
# 35.539768 127.68321999999999
# [30.0000063413623, 127.00796326458243]
# 36.0931448 129.23335600000001
# [33.00000380481738, 129.00477795874946]
# 35.7404061 128.37606599999998
# [32.00000380481738, 128.00477795874946]
# 36.6313946 128.508219
# [32.000005073089845, 128.00637061166594]
# ...

# %%
for ix, row in df.iterrows():
    location = (row['Y-좌표'], row['X-좌표'])
#     folium.Marker(location, popup=row['피해면적_합계']).add_to(map_osm)
    folium.CircleMarker(location,radius=row['피해면적_합계']/20,color='#3186cc',fill_color='#3186cc', popup=row['피해면적_합계']).add_to(map_osm)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df = pd.read_csv('C:\\Users\\noteland\\Documents\\forest\\sanbul4.csv',encoding='cp949')
df.columns = df.columns.str.replace(' ','')

# %%
df.loc[df['발생원인_구분'] == '건', '발생원인'] =1
df.loc[df['발생원인_구분'] == '기', '발생원인'] =2
df.loc[df['발생원인_구분'] == '논', '발생원인'] =3
df.loc[df['발생원인_구분'] == '담', '발생원인'] =4
df.loc[df['발생원인_구분'] == '성', '발생원인'] =5
df.loc[df['발생원인_구분'] == '쓰', '발생원인'] =6
df.loc[df['발생원인_구분'] == '어', '발생원인'] =7
df.loc[df['발생원인_구분'] == '입', '발생원인'] =8
df = df[['발생원인','기온','습도','풍향','풍속']]

# %%
df.describe()
# Out:
#               발생원인           기온           습도           풍향           풍속
# count  3697.000000  3651.000000  3651.000000  3651.000000  3651.000000
# mean      5.123343    14.210299    31.743084   224.196111     3.266667
# std       2.486531     8.562068    15.952764    94.502759     1.857258
# min       1.000000   -15.700000     7.000000     0.000000     0.000000
# 25%       3.000000     8.500000    20.000000   160.000000     1.900000
# 50%       5.000000    14.800000    28.000000   250.000000     3.000000
# 75%       8.000000    20.200000    39.000000   290.000000     4.300000
# max       8.000000    38.100000    99.000000   360.000000    14.700000
