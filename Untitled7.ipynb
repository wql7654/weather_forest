# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.io.json import json_normalize
import folium
import missingno as msno

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
df = pd.read_csv('기상인자와 온열질환자.csv',encoding='cp949')
df.columns = df.columns.str.replace(' ','')
df.columns
# Out:
# Index(['최고기온', '온열질환자', '풍속', '상대습도'], dtype='object')

# %%
df=df[['최고기온', '풍속', '상대습도','온열질환자']]
df.corr()
# Out:
#            최고기온        풍속      상대습도     온열질환자
# 최고기온   1.000000 -0.148100 -0.155008  0.537139
# 풍속    -0.148100  1.000000  0.069253 -0.065611
# 상대습도  -0.155008  0.069253  1.000000 -0.051092
# 온열질환자  0.537139 -0.065611 -0.051092  1.000000

# %%
csv2.corr()
# Out:
#            최고기온        풍속      상대습도     온열질환자
# 최고기온   1.000000 -0.148100 -0.155008  0.537139
# 풍속    -0.148100  1.000000  0.069253 -0.065611
# 상대습도  -0.155008  0.069253  1.000000 -0.051092
# 온열질환자  0.537139 -0.065611 -0.051092  1.000000

# %%
csv2=df.dropna(how='any')

# %%
sns.pairplot(df)

# %%
sns.set_style('whitegrid')
sns.lmplot(
    x="최고기온",
    y="풍속",
    data=df,
    fit_reg=False,
    hue='온열질환자',
    palette="Set1")
